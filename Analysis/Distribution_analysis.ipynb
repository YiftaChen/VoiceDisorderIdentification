# %%
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pandas as pd


# %matplotlib qt

# %% [markdown]
# ## Male Analysis

# %%
def sum_pathologies(path_tree):
    return {pathology:sum(sub_pathologies.values()) for (pathology,sub_pathologies) in path_tree.items()}


def create_pie_chart(kv_dict,title=None, size="big"):
    # #define data
    data = kv_dict.values()
    labels = kv_dict.keys()
    # labels = ['label1', 'label2', 'label3']

    # #define Seaborn color palette to use
    # custom_palette = sns.color_palette("Paired", 9)

    colors = sns.color_palette('Paired',13)
    colors.pop(5)
    # #create pie chart
    if size == "big":
        plt.figure(figsize=(8, 6), dpi=160)
    else:
        plt.figure(figsize=(4, 3), dpi=80)
    if title != None:
        plt.title(title)
    def my_autopct(pct):
        return ('%.0f%%' % pct) if pct >= 1 else ''
    plt.pie(data, labels = labels, colors = colors, autopct=my_autopct)
    plt.show()

# %%
male = {}
with open("male_pathologies.json",'r') as f:
    male = json.load(f)

female = {}
with open("female_pathologies.json",'r') as f:
    female = json.load(f)

both = {}
with open("both_genders_pathologies.json",'r') as f:
    both = json.load(f)


male_summed = sum_pathologies(male)
female_summed = sum_pathologies(female)
both_summed = sum_pathologies(both)

# %%
male = {}
with open("male_pathologies.json",'r') as f:
    male = json.load(f)
male_summed = sum_pathologies(male)

# %%
create_pie_chart(male_summed)

# %%
for pathology,sub_pathologies in male.items():
#     print(sub_pathologies)
    create_pie_chart(sub_pathologies, title=f"{pathology} male",size="small")

# %% [markdown]
# ## Female Analysis

# %%
female = {}
with open("female_pathologies.json",'r') as f:
    female = json.load(f)
female_pie = female_summed
female_pie.pop('Contact pachydermia', None)
female_pie.pop('Scar on the vocal cords after surgery', None)
# Out:
# 3

# %%
create_pie_chart(female_pie)

# %%
for pathology,sub_pathologies in female.items():
#     print(sub_pathologies)
    create_pie_chart(sub_pathologies, title=f"{pathology} female",size="small")

# %% [markdown]
# ## Both Genders

# %%
both = {}
with open("both_genders_pathologies.json",'r') as f:
    both = json.load(f)
both_summed = sum_pathologies(both)
create_pie_chart(both_summed)

# %%
for pathology,sub_pathologies in both.items():
#     print(sub_pathologies)
    create_pie_chart(sub_pathologies, title=f"{pathology} both",size="small")

# %%
df = pd.DataFrame([female_summed,male_summed],index=['female','male'])

df
# Out:
#         Benign vocal cord lesions  Cancer  Contact pachydermia  Dystonia  \
# female                         98      16                    2        42
# male                           38      52                   72        22
#
#         Functional Hoarseness  Healthy  Hyperfunktionelle Dysphonie  \
# female                    150      428                          167
# male                       53      259                           46
#
#         Inflamation of the voice box  Old Voice  \
# female                            57         27
# male                              83         13
#
#         Scar on the vocal cords after surgery  Weakness of vocal cords
# female                                      3                      144
# male                                       83                       83
